# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow==2.8.0 tensorflow-gpu==2.8.0 opencv-python mediapipe scikit-learn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.8.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (2.8.0)
# Requirement already satisfied: tensorflow-gpu==2.8.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (2.8.0)
# Requirement already satisfied: opencv-python in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (4.10.0.82)
# Requirement already satisfied: mediapipe in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (0.10.11)
# Requirement already satisfied: scikit-learn in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (1.3.2)
# Requirement already satisfied: matplotlib in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (3.7.5)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorflow==2.8.0) (1.64.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: jax in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from mediapipe) (0.4.13)
# Requirement already satisfied: opencv-contrib-python in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from mediapipe) (4.10.0.82)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from mediapipe) (0.4.7)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.43.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: CFFI>=1.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.0.3)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from jax->mediapipe) (7.1.0)
# Requirement already satisfied: pycparser in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\fabri\miniconda3\envs\lenmov\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.2)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  +
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == 27:
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len(results.left_hand_landmarks.landmark)
#
# NameError: name 'results' is not defined

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
#lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test

# %%
np.save('0', result_test)

# %%
np.load('0.npy')

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('Fruits')

# Actions that we try to detect
actions = np.array(['Banano', 'Coco', 'Durazno', 'Manzana', 'Piña'])
########### Este listas de ALS, cambiar LSC #########

# Thirty videos worth of data
no_sequences = 50

# Videos are going to be 30 frames in length
sequence_length = 25

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# Guardar - primero video como clave puntos

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):#start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Banano': 0, 'Coco': 1, 'Durazno': 2, 'Manzana': 3, 'Piña': 4}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (250, 25, 1662)

# %%
np.array(labels).shape
# Out:
# (250,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (250, 25, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (13, 5)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, LSTM, Dense, Flatten
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
# Modelo 1
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(20,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(128, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# Modelo 2
# Crear el modelo secuencial
model = Sequential()

# Añadir una capa convolucional
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(25, 1662)))

# Añadir una capa de pooling
model.add(MaxPooling1D(pool_size=2))

# Añadir una segunda capa convolucional
model.add(Conv1D(128, kernel_size=3, activation='relu'))

# Añadir una segunda capa de pooling
model.add(MaxPooling1D(pool_size=2))

# Añadir una tercera capa convolucional
model.add(Conv1D(128, kernel_size=3, activation='relu'))

# Utilizar GlobalMaxPooling1D en lugar de MaxPooling1D para evitar problemas de tamaño
model.add(GlobalMaxPooling1D())

# Aplanar la salida antes de las capas densas
model.add(Flatten())

# Añadir una capa densa
model.add(Dense(64, activation='relu'))

# Añadir una segunda capa densa
model.add(Dense(64, activation='relu'))

# Añadir una tercera capa densa
model.add(Dense(32, activation='relu'))

# Añadir una cuarta capa densa
model.add(Dense(32, activation='relu'))

# Añadir la capa de salida
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# Modelo 1
# Compilar el modelo
model.compile(optimizer="Adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Modelo 2
# Compilar el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=400, callbacks=[tb_callback])
# Out:
# Epoch 1/400
# 8/8 [==============================] - 1s 12ms/step - loss: 7.8303 - accuracy: 0.3924
# Epoch 2/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.9136 - accuracy: 0.6414
# Epoch 3/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0441 - accuracy: 0.6498
# Epoch 4/400
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9737 - accuracy: 0.6667
# Epoch 5/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8800 - accuracy: 0.6709
# Epoch 6/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7805 - accuracy: 0.7679
# Epoch 7/400
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6831 - accuracy: 0.7890
# Epoch 8/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6036 - accuracy: 0.8354
# Epoch 9/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5522 - accuracy: 0.8397
# Epoch 10/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4491 - accuracy: 0.8903
# Epoch 11/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3824 - accuracy: 0.9156
# Epoch 12/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3380 - accuracy: 0.9072
# Epoch 13/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3065 - accuracy: 0.9030
# Epoch 14/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2954 - accuracy: 0.8987
# Epoch 15/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2290 - accuracy: 0.9367
# Epoch 16/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1595 - accuracy: 0.9620
# Epoch 17/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1173 - accuracy: 0.9662
# Epoch 18/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0834 - accuracy: 0.9705
# Epoch 19/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0563 - accuracy: 0.9831
# Epoch 20/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0918 - accuracy: 0.9705
# Epoch 21/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0564 - accuracy: 0.9789
# Epoch 22/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0747 - accuracy: 0.9747
# Epoch 23/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0444 - accuracy: 0.9916
# Epoch 24/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0729 - accuracy: 0.9747
# Epoch 25/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9662
# Epoch 26/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 27/400
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0171 - accuracy: 0.9916
# Epoch 28/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0101 - accuracy: 0.9958
# Epoch 29/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 30/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 31/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 32/400
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 33/400
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 34/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 35/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 36/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 37/400
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 38/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 39/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 40/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 41/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 42/400
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 43/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 44/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 45/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 46/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 47/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 48/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 49/400
# 8/8 [==============================] - 0s 11ms/step - loss: 9.2013e-04 - accuracy: 1.0000
# Epoch 50/400
# 8/8 [==============================] - 0s 12ms/step - loss: 8.8505e-04 - accuracy: 1.0000
# Epoch 51/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 52/400
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 53/400
# 8/8 [==============================] - 0s 9ms/step - loss: 7.3061e-04 - accuracy: 1.0000
# Epoch 54/400
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 55/400
# 8/8 [==============================] - 0s 11ms/step - loss: 8.1246e-04 - accuracy: 1.0000
# Epoch 56/400
# 8/8 [==============================] - 0s 11ms/step - loss: 8.2560e-04 - accuracy: 1.0000
# Epoch 57/400
# 8/8 [==============================] - 0s 11ms/step - loss: 7.5403e-04 - accuracy: 1.0000
# Epoch 58/400
# 8/8 [==============================] - 0s 11ms/step - loss: 7.8761e-04 - accuracy: 1.0000
# Epoch 59/400
# 8/8 [==============================] - 0s 12ms/step - loss: 7.4280e-04 - accuracy: 1.0000
# Epoch 60/400
# 8/8 [==============================] - 0s 11ms/step - loss: 6.4095e-04 - accuracy: 1.0000
# Epoch 61/400
# 8/8 [==============================] - 0s 11ms/step - loss: 7.1542e-04 - accuracy: 1.0000
# Epoch 62/400
# 8/8 [==============================] - 0s 11ms/step - loss: 6.0451e-04 - accuracy: 1.0000
# Epoch 63/400
# 8/8 [==============================] - 0s 12ms/step - loss: 6.0465e-04 - accuracy: 1.0000
# Epoch 64/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.9868e-04 - accuracy: 1.0000
# Epoch 65/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.7014e-04 - accuracy: 1.0000
# Epoch 66/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.9460e-04 - accuracy: 1.0000
# Epoch 67/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.8611e-04 - accuracy: 1.0000
# Epoch 68/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.6618e-04 - accuracy: 1.0000
# Epoch 69/400
# 8/8 [==============================] - 0s 12ms/step - loss: 5.2054e-04 - accuracy: 1.0000
# Epoch 70/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.8934e-04 - accuracy: 1.0000
# Epoch 71/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.2412e-04 - accuracy: 1.0000
# Epoch 72/400
# 8/8 [==============================] - 0s 9ms/step - loss: 4.7745e-04 - accuracy: 1.0000
# Epoch 73/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.7115e-04 - accuracy: 1.0000
# Epoch 74/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.5482e-04 - accuracy: 1.0000
# Epoch 75/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.8496e-04 - accuracy: 1.0000
# Epoch 76/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.9037e-04 - accuracy: 1.0000
# Epoch 77/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.6472e-04 - accuracy: 1.0000
# Epoch 78/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.1702e-04 - accuracy: 1.0000
# Epoch 79/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.4803e-04 - accuracy: 1.0000
# Epoch 80/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.1401e-04 - accuracy: 1.0000
# Epoch 81/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.8283e-04 - accuracy: 1.0000
# Epoch 82/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.6709e-04 - accuracy: 1.0000
# Epoch 83/400
# 8/8 [==============================] - 0s 12ms/step - loss: 3.6408e-04 - accuracy: 1.0000
# Epoch 84/400
# 8/8 [==============================] - 0s 12ms/step - loss: 3.5757e-04 - accuracy: 1.0000
# Epoch 85/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3
400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.9277e-05 - accuracy: 1.0000
# Epoch 217/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.8918e-05 - accuracy: 1.0000
# Epoch 218/400
# 8/8 [==============================] - 0s 9ms/step - loss: 5.8117e-05 - accuracy: 1.0000
# Epoch 219/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.8196e-05 - accuracy: 1.0000
# Epoch 220/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.9477e-05 - accuracy: 1.0000
# Epoch 221/400
# 8/8 [==============================] - 0s 9ms/step - loss: 5.6852e-05 - accuracy: 1.0000
# Epoch 222/400
# 8/8 [==============================] - 0s 12ms/step - loss: 5.3982e-05 - accuracy: 1.0000
# Epoch 223/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.7204e-05 - accuracy: 1.0000
# Epoch 224/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.4862e-05 - accuracy: 1.0000
# Epoch 225/400
# 8/8 [==============================] - 0s 10ms/step - loss: 5.5555e-05 - accuracy: 1.0000
# Epoch 226/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.1649e-05 - accuracy: 1.0000
# Epoch 227/400
# 8/8 [==============================] - 0s 12ms/step - loss: 5.5632e-05 - accuracy: 1.0000
# Epoch 228/400
# 8/8 [==============================] - 0s 10ms/step - loss: 5.2708e-05 - accuracy: 1.0000
# Epoch 229/400
# 8/8 [==============================] - 0s 9ms/step - loss: 5.2237e-05 - accuracy: 1.0000
# Epoch 230/400
# 8/8 [==============================] - 0s 11ms/step - loss: 5.2543e-05 - accuracy: 1.0000
# Epoch 231/400
# 8/8 [==============================] - 0s 12ms/step - loss: 5.0387e-05 - accuracy: 1.0000
# Epoch 232/400
# 8/8 [==============================] - 0s 9ms/step - loss: 4.9895e-05 - accuracy: 1.0000
# Epoch 233/400
# 8/8 [==============================] - 0s 9ms/step - loss: 4.9478e-05 - accuracy: 1.0000
# Epoch 234/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.9385e-05 - accuracy: 1.0000
# Epoch 235/400
# 8/8 [==============================] - 0s 10ms/step - loss: 4.9344e-05 - accuracy: 1.0000
# Epoch 236/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.8136e-05 - accuracy: 1.0000
# Epoch 237/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.8239e-05 - accuracy: 1.0000
# Epoch 238/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.7789e-05 - accuracy: 1.0000
# Epoch 239/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.8179e-05 - accuracy: 1.0000
# Epoch 240/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.8166e-05 - accuracy: 1.0000
# Epoch 241/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.6679e-05 - accuracy: 1.0000
# Epoch 242/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.7146e-05 - accuracy: 1.0000
# Epoch 243/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.6439e-05 - accuracy: 1.0000
# Epoch 244/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.4783e-05 - accuracy: 1.0000
# Epoch 245/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.4562e-05 - accuracy: 1.0000
# Epoch 246/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.4433e-05 - accuracy: 1.0000
# Epoch 247/400
# 8/8 [==============================] - 0s 14ms/step - loss: 4.3620e-05 - accuracy: 1.0000
# Epoch 248/400
# 8/8 [==============================] - 0s 9ms/step - loss: 4.3754e-05 - accuracy: 1.0000
# Epoch 249/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.2598e-05 - accuracy: 1.0000
# Epoch 250/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.2624e-05 - accuracy: 1.0000
# Epoch 251/400
# 8/8 [==============================] - 0s 9ms/step - loss: 4.3310e-05 - accuracy: 1.0000
# Epoch 252/400
# 8/8 [==============================] - 0s 9ms/step - loss: 4.2568e-05 - accuracy: 1.0000
# Epoch 253/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.1645e-05 - accuracy: 1.0000
# Epoch 254/400
# 8/8 [==============================] - 0s 12ms/step - loss: 4.1600e-05 - accuracy: 1.0000
# Epoch 255/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.3337e-05 - accuracy: 1.0000
# Epoch 256/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.0548e-05 - accuracy: 1.0000
# Epoch 257/400
# 8/8 [==============================] - 0s 11ms/step - loss: 4.1646e-05 - accuracy: 1.0000
# Epoch 258/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.9983e-05 - accuracy: 1.0000
# Epoch 259/400
# 8/8 [==============================] - 0s 12ms/step - loss: 3.8925e-05 - accuracy: 1.0000
# Epoch 260/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.8723e-05 - accuracy: 1.0000
# Epoch 261/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.9375e-05 - accuracy: 1.0000
# Epoch 262/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.7750e-05 - accuracy: 1.0000
# Epoch 263/400
# 8/8 [==============================] - 0s 10ms/step - loss: 3.9901e-05 - accuracy: 1.0000
# Epoch 264/400
# 8/8 [==============================] - 0s 9ms/step - loss: 3.8397e-05 - accuracy: 1.0000
# Epoch 265/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.7106e-05 - accuracy: 1.0000
# Epoch 266/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.6727e-05 - accuracy: 1.0000
# Epoch 267/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.7020e-05 - accuracy: 1.0000
# Epoch 268/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.6318e-05 - accuracy: 1.0000
# Epoch 269/400
# 8/8 [==============================] - 0s 12ms/step - loss: 3.5858e-05 - accuracy: 1.0000
# Epoch 270/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.6722e-05 - accuracy: 1.0000
# Epoch 271/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.5192e-05 - accuracy: 1.0000
# Epoch 272/400
# 8/8 [==============================] - 0s 10ms/step - loss: 3.4845e-05 - accuracy: 1.0000
# Epoch 273/400
# 8/8 [==============================] - 0s 9ms/step - loss: 3.4919e-05 - accuracy: 1.0000
# Epoch 274/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.4233e-05 - accuracy: 1.0000
# Epoch 275/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.3958e-05 - accuracy: 1.0000
# Epoch 276/400
# 8/8 [==============================] - 0s 10ms/step - loss: 3.3664e-05 - accuracy: 1.0000
# Epoch 277/400
# 8/8 [==============================] - 0s 9ms/step - loss: 3.4038e-05 - accuracy: 1.0000
# Epoch 278/400
# 8/8 [==============================] - 0s 12ms/step - loss: 3.3021e-05 - accuracy: 1.0000
# Epoch 279/400
# 8/8 [==============================] - 0s 12ms/step - loss: 3.3056e-05 - accuracy: 1.0000
# Epoch 280/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.2763e-05 - accuracy: 1.0000
# Epoch 281/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.2350e-05 - accuracy: 1.0000
# Epoch 282/400
# 8/8 [==============================] - 0s 10ms/step - loss: 3.2784e-05 - accuracy: 1.0000
# Epoch 283/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.1898e-05 - accuracy: 1.0000
# Epoch 284/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.2220e-05 - accuracy: 1.0000
# Epoch 285/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.1571e-05 - accuracy: 1.0000
# Epoch 286/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.1068e-05 - accuracy: 1.0000
# Epoch 287/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.0472e-05 - accuracy: 1.0000
# Epoch 288/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.0497e-05 - accuracy: 1.0000
# Epoch 289/400
# 8/8 [==============================] - 0s 11ms/step - loss: 3.0710e-05 - accuracy: 1.0000
# Epoch 290/400
# 8/8 [==============================] - 0s 12ms/step - loss: 3.0710e-05 - accuracy: 1.0000
# Epoch 291/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.9613e-05 - accuracy: 1.0000
# Epoch 292/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.9399e-05 - accuracy: 1.0000
# Epoch 293/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.9385e-05 - accuracy: 1.0000
# Epoch 294/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.8988e-05 - accuracy: 1.0000
# Epoch 295/400
# 8/8 [==============================] - 0s 9ms/step - loss: 2.8941e-05 - accuracy: 1.0000
# Epoch 296/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.8571e-05 - accuracy: 1.0000
# Epoch 297/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.8539e-05 - accuracy: 1.0000
# Epoch 298/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.8686e-05 - accuracy: 1.0000
# Epoch 299/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.7907e-05 - accuracy: 1.0000
# Epoch 300/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.7465e-05 - accuracy: 1.0000
# Epoch 301/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.7486e-05 - accuracy: 1.0000
# Epoch 302/400
# 8/8 [==============================] - 0s 9ms/step - loss: 2.7763e-05 - accuracy: 1.0000
# Epoch 303/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.7074e-05 - accuracy: 1.0000
# Epoch 304/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6890e-05 - accuracy: 1.0000
# Epoch 305/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6353e-05 - accuracy: 1.0000
# Epoch 306/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6264e-05 - accuracy: 1.0000
# Epoch 307/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6123e-05 - accuracy: 1.0000
# Epoch 308/400
# 8/8 [==============================] - 0s 9ms/step - loss: 2.6028e-05 - accuracy: 1.0000
# Epoch 309/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.5954e-05 - accuracy: 1.0000
# Epoch 310/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.5222e-05 - accuracy: 1.0000
# Epoch 311/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6654e-05 - accuracy: 1.0000
# Epoch 312/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.5331e-05 - accuracy: 1.0000
# Epoch 313/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.7032e-05 - accuracy: 1.0000
# Epoch 314/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6939e-05 - accuracy: 1.0000
# Epoch 315/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.5868e-05 - accuracy: 1.0000
# Epoch 316/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4039e-05 - accuracy: 1.0000
# Epoch 317/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.4371e-05 - accuracy: 1.0000
# Epoch 318/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3550e-05 - accuracy: 1.0000
# Epoch 319/400
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4228e-05 - accuracy: 1.0000
# Epoch 320/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3638e-05 - accuracy: 1.0000
# Epoch 321/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3172e-05 - accuracy: 1.0000
# Epoch 322/400
# 8/8 [==============================] - 0s 9ms/step - loss: 2.3087e-05 - accuracy: 1.0000
# Epoch 323/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3108e-05 - accuracy: 1.0000
# Epoch 324/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.2895e-05 - accuracy: 1.0000
# Epoch 325/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.2807e-05 - accuracy: 1.0000
# Epoch 326/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.2791e-05 - accuracy: 1.0000
# Epoch 327/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.2244e-05 - accuracy: 1.0000
# Epoch 328/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.2196e-05 - accuracy: 1.0000
# Epoch 329/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.2397e-05 - accuracy: 1.0000
# Epoch 330/400
# 8/8 [==============================] - 0s 10ms/step - loss: 2.1908e-05 - accuracy: 1.0000
# Epoch 331/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.1855e-05 - accuracy: 1.0000
# Epoch 332/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.1895e-05 - accuracy: 1.0000
# Epoch 333/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.1783e-05 - accuracy: 1.0000
# Epoch 334/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.1275e-05 - accuracy: 1.0000
# Epoch 335/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.1413e-05 - accuracy: 1.0000
# Epoch 336/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.1240e-05 - accuracy: 1.0000
# Epoch 337/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.0801e-05 - accuracy: 1.0000
# Epoch 338/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.0590e-05 - accuracy: 1.0000
# Epoch 339/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.0618e-05 - accuracy: 1.0000
# Epoch 340/400
# 8/8 [==============================] - 0s 12ms/step - loss: 2.0217e-05 - accuracy: 1.0000
# Epoch 341/400
# 8/8 [==============================] - 0s 9ms/step - loss: 2.0274e-05 - accuracy: 1.0000
# Epoch 342/400
# 8/8 [==============================] - 0s 11ms/step - loss: 2.0585e-05 - accuracy: 1.0000
# Epoch 343/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.9948e-05 - accuracy: 1.0000
# Epoch 344/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.9616e-05 - accuracy: 1.0000
# Epoch 345/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.9575e-05 - accuracy: 1.0000
# Epoch 346/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.9488e-05 - accuracy: 1.0000
# Epoch 347/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.9785e-05 - accuracy: 1.0000
# Epoch 348/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.9768e-05 - accuracy: 1.0000
# Epoch 349/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.9397e-05 - accuracy: 1.0000
# Epoch 350/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.8890e-05 - accuracy: 1.0000
# Epoch 351/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.8878e-05 - accuracy: 1.0000
# Epoch 352/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.8557e-05 - accuracy: 1.0000
# Epoch 353/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.8743e-05 - accuracy: 1.0000
# Epoch 354/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.8550e-05 - accuracy: 1.0000
# Epoch 355/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.8326e-05 - accuracy: 1.0000
# Epoch 356/400
# 8/8 [==============================] - 0s 9ms/step - loss: 1.8162e-05 - accuracy: 1.0000
# Epoch 357/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.8564e-05 - accuracy: 1.0000
# Epoch 358/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7983e-05 - accuracy: 1.0000
# Epoch 359/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7832e-05 - accuracy: 1.0000
# Epoch 360/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7639e-05 - accuracy: 1.0000
# Epoch 361/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7678e-05 - accuracy: 1.0000
# Epoch 362/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7446e-05 - accuracy: 1.0000
# Epoch 363/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7165e-05 - accuracy: 1.0000
# Epoch 364/400
# 8/8 [==============================] - 0s 9ms/step - loss: 1.7159e-05 - accuracy: 1.0000
# Epoch 365/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6993e-05 - accuracy: 1.0000
# Epoch 366/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.6885e-05 - accuracy: 1.0000
# Epoch 367/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.6739e-05 - accuracy: 1.0000
# Epoch 368/400
# 8/8 [==============================] - 0s 10ms/step - loss: 1.6628e-05 - accuracy: 1.0000
# Epoch 369/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.6657e-05 - accuracy: 1.0000
# Epoch 370/400
# 8/8 [==============================] - 0s 14ms/step - loss: 1.6464e-05 - accuracy: 1.0000
# Epoch 371/400
# 8/8 [==============================] - 0s 10ms/step - loss: 1.6350e-05 - accuracy: 1.0000
# Epoch 372/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.6314e-05 - accuracy: 1.0000
# Epoch 373/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6299e-05 - accuracy: 1.0000
# Epoch 374/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.6424e-05 - accuracy: 1.0000
# Epoch 375/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.5951e-05 - accuracy: 1.0000
# Epoch 376/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.5778e-05 - accuracy: 1.0000
# Epoch 377/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.5721e-05 - accuracy: 1.0000
# Epoch 378/400
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5658e-05 - accuracy: 1.0000
# Epoch 379/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5520e-05 - accuracy: 1.0000
# Epoch 380/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.5386e-05 - accuracy: 1.0000
# Epoch 381/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5639e-05 - accuracy: 1.0000
# Epoch 382/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.5246e-05 - accuracy: 1.0000
# Epoch 383/400
# 8/8 [==============================] - 0s 13ms/step - loss: 1.5240e-05 - accuracy: 1.0000
# Epoch 384/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.5106e-05 - accuracy: 1.0000
# Epoch 385/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4844e-05 - accuracy: 1.0000
# Epoch 386/400
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4994e-05 - accuracy: 1.0000
# Epoch 387/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4732e-05 - accuracy: 1.0000
# Epoch 388/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4959e-05 - accuracy: 1.0000
# Epoch 389/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4908e-05 - accuracy: 1.0000
# Epoch 390/400
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4451e-05 - accuracy: 1.0000
# Epoch 391/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4390e-05 - accuracy: 1.0000
# Epoch 392/400
# 8/8 [==============================] - 0s 10ms/step - loss: 1.4425e-05 - accuracy: 1.0000
# Epoch 393/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4258e-05 - accuracy: 1.0000
# Epoch 394/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4109e-05 - accuracy: 1.0000
# Epoch 395/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.4027e-05 - accuracy: 1.0000
# Epoch 396/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4042e-05 - accuracy: 1.0000
# Epoch 397/400
# 8/8 [==============================] - 0s 10ms/step - loss: 1.4211e-05 - accuracy: 1.0000
# Epoch 398/400
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4144e-05 - accuracy: 1.0000
# Epoch 399/400
# 8/8 [==============================] - 0s 12ms/step - loss: 1.3692e-05 - accuracy: 1.0000
# Epoch 400/400
# 8/8 [==============================] - 0s 9ms/step - loss: 1.3923e-05 - accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 23, 64)            319168
#
#  max_pooling1d (MaxPooling1D  (None, 11, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 9, 128)            24704
#
#  max_pooling1d_1 (MaxPooling  (None, 4, 128)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 2, 128)            49280
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dense_4 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 408,869
# Trainable params: 408,869
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[1])]
# Out:
# 'Piña'

# %%
actions[np.argmax(y_test[1])]
# Out:
# 'Piña'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('prueba5.h5')

# %%
#del model

# %%
model.load_weights('prueba5.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[12,  0],
#         [ 1,  0]],
#
#        [[12,  0],
#         [ 0,  1]],
#
#        [[ 9,  0],
#         [ 0,  4]],
#
#        [[12,  0],
#         [ 0,  1]],
#
#        [[ 6,  1],
#         [ 0,  6]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9230769230769231

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245),(163,117,245),(17,117,245)]
def prob_viz (res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# NameError: name 'prob_viz' is not defined

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-25:]
        
        if len(sequence) == 25:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == 27:
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Coco
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Banano
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Durazno
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Piña
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Manzana
